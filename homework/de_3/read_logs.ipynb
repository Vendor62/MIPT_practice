# %%
import pandas as pd

# %%
logs = pd.read_csv('user_actions.csv')

# %%
logs
# Out:
#       user_id            timestamp     action_type  user_message_length  \
# 0   138849259  2025-03-29 19:30:03  /start command                    0
# 1   138849259  2025-03-29 19:30:14            text                    9
# 2   138849259  2025-03-29 19:30:31            text                   23
# 3   138849259  2025-03-29 19:30:45         command                    5
# 4   138849259  2025-03-29 19:30:49         command                    5
# 5   138849259  2025-03-29 19:31:03         command                    7
# 6   138849259  2025-03-29 19:31:15            text                    5
# 7   138849259  2025-03-29 19:31:22            text                    5
# 8   138849259  2025-03-29 19:31:27            text                    5
# 9   138849259  2025-03-29 19:31:31            text                    5
# 10  138849259  2025-03-29 19:31:35            text                    5
# 11  138849259  2025-03-29 19:31:56            text                    5
# ...
